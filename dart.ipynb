# %%
import dart_fss as dart
import pandas as pd

# %%
api_key = '878c9e7d2f3d919a8759f7cb01ae8f1a5ddff909'
dart.set_api_key(api_key=api_key)

corp_list = dart.get_corp_list()

list = ['삼성전자', 'LG디스플레이', '삼성SDI', '삼성에스디에스', 'LG전자', 'SK하이닉스']

# %%
#삼성전자
corp = corp_list.find_by_corp_name(list[0], exactly=True)[0]
samsungelc_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
# 재무제표 관련
corp_fs = samsungelc_fs[0].drop([samsungelc_fs[0].columns[0], samsungelc_fs[0].columns[2], samsungelc_fs[0].columns[3], samsungelc_fs[0].columns[4], samsungelc_fs[0].columns[5], samsungelc_fs[0].columns[6],samsungelc_fs[0].columns[7]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련
corp_is = samsungelc_fs[1].drop([samsungelc_fs[1].columns[0], samsungelc_fs[1].columns[2], samsungelc_fs[1].columns[3], samsungelc_fs[1].columns[4], samsungelc_fs[1].columns[5]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금(결손금)', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['수익(매출액)', '기본주당이익(손실)']))]
is_info = is_info.set_index('is')

# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[0] + '_fs.xlsx')
corp_is.to_excel(list[0] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장

fs_info.to_excel(list[0] + '_fs_info.xlsx')

is_info.to_excel(list[0] + '_is_info.xlsx')

# %%
fs_info
# Out:
#                         20221231              20220930              20220630  \
# bs
# 자산총계       448,424,507,000,000.0 470,278,409,000,000.0 448,040,650,000,000.0
# 이익잉여금(결손금) 337,946,407,000,000.0 316,890,272,000,000.0 310,216,785,000,000.0
# 자본총계       354,749,604,000,000.0 344,906,889,000,000.0 327,906,664,000,000.0
# ROA           0.7536305481181027    0.6738354683852815     0.692385356105523
# ROE           0.9526336412767356     0.918770491707981    0.9460520906034408
#
#                         20220331              20211231              20210930  \
# bs
# 자산총계       439,326,959,000,000.0 426,621,158,000,000.0 410,420,718,000,000.0
# 이익잉여금(결손금) 301,743,152,000,000.0 293,064,763,000,000.0 284,826,992,000,000.0
# 자본총계       315,290,919,000,000.0 304,899,931,000,000.0 296,766,118,000,000.0
# ROA           0.6868304933683799    0.6869438083518586    0.6939878507790145
# ROE           0.9570309000875474    0.9611834349677173    0.9597692415816822
#
# ...

# %%
#LG디스플레이
corp = corp_list.find_by_corp_name(list[1], exactly=True)[0]
lgdis_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
lgdis_fs[0]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
#                                                                                                        concept_id
# 0                             ifrs-full_CurrentAssets
# 1                    ifrs-full_CashAndCashEquivalents
# 2   dart_ShortTermDepositsNotClassifiedAsCashEquiv...
# 3                       dart_ShortTermTradeReceivable
# 4                      dart_ShortTermOtherReceivables
# 5               ifrs-full_OtherCurrentFinancialAssets
# 6                               ifrs-full_Inventories
# 7                          ifrs-full_CurrentTaxAssets
# 8                             dart_OtherCurrentAssets
# 9                          ifrs-full_NoncurrentAssets
# 10  dart_LongTermDepositsNotClassifiedAsCashEquiva...
# 11  ifrs-full_InvestmentAccountedForUsingEquityMethod
# 12  dart_LongTermTradeAndOtherNonCurrentReceivable...
# ...

# %%
# 재무제표 관련
corp_fs = lgdis_fs[0].drop([lgdis_fs[0].columns[0], lgdis_fs[0].columns[2], lgdis_fs[0].columns[3], lgdis_fs[0].columns[4], lgdis_fs[0].columns[5], lgdis_fs[0].columns[6]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련
corp_is = lgdis_fs[2].drop([lgdis_fs[2].columns[0], lgdis_fs[2].columns[2], lgdis_fs[2].columns[3], lgdis_fs[2].columns[4], lgdis_fs[2].columns[5],  lgdis_fs[2].columns[6]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금(결손금)', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['매출', '기본주당이익(손실)']))]
is_info = is_info.set_index('is')

# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[1] + '_fs.xlsx')
corp_is.to_excel(list[1] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장
# fs_info = pd.merge(Retained_Earnings, Full_Equity)
# fs_info = pd.merge(fs_info, Full_Assets)
fs_info.to_excel(list[1] + '_fs_info.xlsx')

is_info.to_excel(list[1] + '_is_info.xlsx')

# %%
fs_info
# Out:
#                        20220930             20220630             20220331  \
# bs
# 자산총계       40,133,950,000,000.0 38,305,442,000,000.0 38,267,145,000,000.0
# 이익잉여금(결손금)  7,278,419,000,000.0  8,072,910,000,000.0  8,325,146,000,000.0
# 자본총계       14,283,603,000,000.0 14,630,334,000,000.0 14,757,226,000,000.0
# ROA         0.18135316857672867  0.21075099459758223  0.21755336072236378
# ROE          0.5095646385579324    0.551792597489572   0.5641403065860752
#
#                        20211231             20210930             20210630  \
# bs
# 자산총계       38,154,515,000,000.0 37,606,183,000,000.0 36,323,689,000,000.0
# 이익잉여금(결손금)  8,541,521,000,000.0  8,526,710,000,000.0  8,109,354,000,000.0
# 자본총계       14,762,501,000,000.0 14,611,637,000,000.0 13,760,723,000,000.0
# ROA         0.22386658564523754  0.22673691717130665  0.22325248958055996
# ROE          0.5785957948453314   0.5835561066840081   0.5893116226523853
#
# ...

# %%
#삼성SDI
corp = corp_list.find_by_corp_name(list[2], exactly=True)[0]
sdi_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
# 재무제표 관련
corp_fs = sdi_fs[0].drop([sdi_fs[0].columns[0], sdi_fs[0].columns[2], sdi_fs[0].columns[3], sdi_fs[0].columns[4], sdi_fs[0].columns[5], sdi_fs[0].columns[6]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련
corp_is = sdi_fs[2].drop([sdi_fs[2].columns[0], sdi_fs[2].columns[2], sdi_fs[2].columns[3], sdi_fs[2].columns[4], sdi_fs[2].columns[5], sdi_fs[2].columns[6]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['매출액', '보통주 기본및희석주당손익']))]
is_info = is_info.set_index('is')

# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[2] + '_fs.xlsx')
corp_is.to_excel(list[2] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장
# fs_info = pd.merge(Retained_Earnings, Full_Equity)
# fs_info = pd.merge(fs_info, Full_Assets)
fs_info.to_excel(list[2] + '_fs_info.xlsx')

is_info.to_excel(list[2] + '_is_info.xlsx')

# %%
sdi_fs[0]
# Out:
#    [D210000] Statement of financial position, current/non-current - Consolidated financial statements (Unit: KRW)  \
#                                                                                                        concept_id
# 0                             ifrs-full_CurrentAssets
# 1                    ifrs-full_CashAndCashEquivalents
# 2           ifrs-full_TradeAndOtherCurrentReceivables
# 3                               ifrs-full_Inventories
# 4   entity00126362_udf_BS_201872675842197_CurrentA...
# 5                             dart_OtherCurrentAssets
# 6                         dart_CurrentDerivativeAsset
# 7                          ifrs-full_NoncurrentAssets
# 8   dart_LongTermTradeAndOtherNonCurrentReceivable...
# 9                   ifrs-full_InvestmentsInAssociates
# 10                ifrs-full_PropertyPlantAndEquipment
# 11        ifrs-full_IntangibleAssetsOtherThanGoodwill
# 12                       ifrs-full_InvestmentProperty
# ...

# %%
#삼성SDS
corp = corp_list.find_by_corp_name(list[3], exactly=True)[0]
sds_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
# 재무제표 관련 부분 추출 / columns 중 계정과목과 필요 데이터만 남기고 drop
corp_fs = sds_fs[0].drop([sds_fs[0].columns[0], sds_fs[0].columns[2], sds_fs[0].columns[3], sds_fs[0].columns[4], sds_fs[0].columns[5], sds_fs[0].columns[6]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련 부분 추출 / columns 중 계정과목과 필요 데이터만 남기고 drop
corp_is = sds_fs[1].drop([sds_fs[1].columns[0], sds_fs[1].columns[2], sds_fs[1].columns[3], sds_fs[1].columns[4], sds_fs[1].columns[5]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['매출액', '보통주 기본주당이익']))]
is_info = is_info.set_index('is')

# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[3] + '_fs.xlsx')
corp_is.to_excel(list[3] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장
# fs_info = pd.merge(Retained_Earnings, Full_Equity)
# fs_info = pd.merge(fs_info, Full_Assets)
fs_info.to_excel(list[3] + '_fs_info.xlsx')

is_info.to_excel(list[3] + '_is_info.xlsx')

# %%
sds_fs[1]
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                                     dart_OtherGains
# 6                                    dart_OtherLosses
# 7                             ifrs-full_FinanceIncome
# 8                    dart_InterestIncomeFinanceIncome
# 9   dart_GainsOnForeignCurrencyTransactionsFiancia...
# 10  dart_GainsOnForeignExchangeTranslationsFinanci...
# 11                             ifrs-full_FinanceCosts
# 12                 dart_InterestExpenseFinanceExpense
# 13  dart_LossesOnForeignCurrencyTransactionsFianci...
# ...

# %%
#LG전자
corp = corp_list.find_by_corp_name(list[4], exactly=True)[0]
lgelc_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
lgelc_fs[1]
# Out:
#    [D310000] Income statement, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                            concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4   entity00401731_udf_IS_201710251846565_TotalSel...
# 5   entity00401731_udf_IS_2017102518467157_TotalSe...
# 6   entity00401731_udf_IS_2017102518468687_TotalSe...
# 7   entity00401731_udf_IS_20171025184610585_TotalS...
# 8                            dart_OperatingIncomeLoss
# 9                             ifrs-full_FinanceIncome
# 10                             ifrs-full_FinanceCosts
# 11  entity00401731_udf_IS_20171025184822589_Income...
# 12                                    dart_OtherGains
# 13                                   dart_OtherLosses
# ...

# %%
# 재무제표 관련
corp_fs = lgelc_fs[0].drop([lgelc_fs[0].columns[0], lgelc_fs[0].columns[2], lgelc_fs[0].columns[3], lgelc_fs[0].columns[4], lgelc_fs[0].columns[5], lgelc_fs[0].columns[6]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련
corp_is = lgelc_fs[1].drop([lgelc_fs[1].columns[0], lgelc_fs[1].columns[2], lgelc_fs[1].columns[3], lgelc_fs[1].columns[4], lgelc_fs[1].columns[5],  lgelc_fs[1].columns[6],   lgelc_fs[1].columns[7]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
# Retained_Earnings = corp_fs.loc[ corp_fs['bs']=='이익잉여금(결손금)']
# Full_Equity = corp_fs.loc[ corp_fs['bs']=='자본총계']
# Full_Assets = corp_fs.loc[ corp_fs['bs']=='자산총계']
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['매출액', '보통주기본주당이익(손실)']))]
is_info = is_info.set_index('is')
# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[4] + '_fs.xlsx')
corp_is.to_excel(list[4] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장
# fs_info = pd.merge(Retained_Earnings, Full_Equity)
# fs_info = pd.merge(fs_info, Full_Assets)
fs_info.to_excel(list[4] + '_fs_info.xlsx')

is_info.to_excel(list[4] + '_is_info.xlsx')

# %%
#SK하이닉스
corp = corp_list.find_by_corp_name(list[5], exactly=True)[0]
sk_fs = corp.extract_fs(bgn_de='20190101', report_tp='quarter')
# Out:
# ...
# Quarterly reports:   0%|          | 0/8 [00:00<?, ?report/s]

# %%
# 재무제표 관련
corp_fs = sk_fs[0].drop([sk_fs[0].columns[0], sk_fs[0].columns[2], sk_fs[0].columns[3], sk_fs[0].columns[4], sk_fs[0].columns[5], sk_fs[0].columns[6]], axis=1)
corp_fs.columns = ['bs', '20221231', '20220930', '20220630', '20220331', '20211231', '20210930', '20210630',
                       '20210331', '20201231', '20200930', '20200630', '20200331', '20191231', '20190930', '20190630',
                       '20190331', '20181231', '20171231', '20161231']

# 손익계산서 관련
corp_is = sk_fs[2].drop([sk_fs[2].columns[0], sk_fs[2].columns[2], sk_fs[2].columns[3], sk_fs[2].columns[4], sk_fs[2].columns[5], sk_fs[2].columns[6]],axis=1)
corp_is.columns = ['is', '20220701-20220930', '20220401-20220630', '20220101-20221231', '20220101-20220930',
                       '20220101-20220630', '20220101-20220331', '20210701-20210930', '20210401-20210630',
                       '20210101-20211231', '20210101-20210930', '20210101-20210630', '20210101-20210331',
                       '20200701-20200930', '20200401-20200630', '20200101-20201231', '20200101-20200930',
                       '20200101-20200630', '20200101-20200331', '20190701-20190930', '20190401-20190630',
                       '20190101-20191231', '20190101-20190930', '20190101-20190630', '20190101-20190331',
                       '20180701-20180930', '20180401-20180630', '20180101-20181231', '20180101-20180930',
                       '20180101-20180630', '20180101-20180331', '20170101-20171231', '20160101-20161231']

# 필요정보 주출
# Retained_Earnings = corp_fs.loc[ corp_fs['bs']=='이익잉여금(결손금)']
# Full_Equity = corp_fs.loc[ corp_fs['bs']=='자본총계']
# Full_Assets = corp_fs.loc[ corp_fs['bs']=='자산총계']
fs_info = corp_fs.loc[corp_fs['bs'].isin(['이익잉여금', '자본총계', '자산총계'])]
fs_info = fs_info.set_index('bs')
fs_info.loc['ROA'] = fs_info.iloc[1] / fs_info.iloc[0]
fs_info.loc['ROE'] = fs_info.iloc[1] / fs_info.iloc[2]
is_info = corp_is.loc[(corp_is['is'].isin(['매출액', '기본주당순이익']))]
is_info = is_info.set_index('is')

# 전체 재무제표 및 손익계산서 저장
corp_fs.to_excel(list[5] + '_fs.xlsx')
corp_is.to_excel(list[5] + '_is.xlsx')

# # 필요정보만 추출한 부분 따로 저장
# fs_info = pd.merge(Retained_Earnings, Full_Equity)
# fs_info = pd.merge(fs_info, Full_Assets)
fs_info.to_excel(list[5] + '_fs_info.xlsx')

is_info.to_excel(list[5] + '_is_info.xlsx')

# %%
sk_fs[2]
# Out:
#    [D431410] Statement of comprehensive income, by function of expense - Consolidated financial statements (Unit: KRW)  \
#                                                                                                             concept_id
# 0                                   ifrs-full_Revenue
# 1                               ifrs-full_CostOfSales
# 2                               ifrs-full_GrossProfit
# 3      dart_TotalSellingGeneralAdministrativeExpenses
# 4                            dart_OperatingIncomeLoss
# 5                             ifrs-full_FinanceIncome
# 6                              ifrs-full_FinanceCosts
# 7   entity00164779_udf_IS_202012292018323_Statemen...
# 8   entity00164779_udf_IS_2020122919587603_Stateme...
# 9   entity00164779_udf_IS_20201229195937796_Statem...
# 10                      ifrs-full_ProfitLossBeforeTax
# 11     ifrs-full_IncomeTaxExpenseContinuingOperations
# 12                               ifrs-full_ProfitLoss
# ...
